# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# ## 2. Background Theory

# %% [markdown]
# ## 3. Mathematical Model

# %% [markdown]
# ## 4. Python Implementation

# %% [markdown]
# ## 5. Experiments

# %% [markdown]
# ## 6. Visualization

# %% [markdown]
# ## 7. Discussion

# %% [markdown]
# ## 8. Conclusion
